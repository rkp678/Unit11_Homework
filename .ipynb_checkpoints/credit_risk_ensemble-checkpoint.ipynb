# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Create our features
X = df.copy()
X.drop("loan_status", axis=1, inplace=True)
X.head()
X = pd.get_dummies(X, drop_first=True) 
# Used this to convert string to numbers so model can calculate numbers. 
# The model could not do math on strings.
X
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0        10500.0    0.1719       375.35     66000.0  27.24          0.0
# 1        25000.0    0.2000       929.09    105000.0  20.23          0.0
# 2        20000.0    0.2000       529.88     56000.0  24.26          0.0
# 3        10000.0    0.1640       353.55     92000.0  31.44          0.0
# 4        22000.0    0.1474       520.39     52000.0  18.76          0.0
# ...          ...       ...          ...         ...    ...          ...
# 68812    10000.0    0.1502       346.76     26000.0   9.60          0.0
# 68813    12000.0    0.2727       368.37     63000.0  29.07          0.0
# 68814     5000.0    0.1992       185.62     52000.0  14.86          0.0
# 68815    40000.0    0.0646      1225.24    520000.0   9.96          0.0
# 68816    16000.0    0.1131       350.36     72000.0   7.02          2.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0                 0.0       8.0      0.0     1609.0  ...
# 1                 0.0      17.0      1.0    18368.0  ...
# 2                 0.0       8.0      0.0    13247.0  ...
# 3                 1.0      10.0      1.0    17996.0  ...
# 4                 1.0      14.0      0.0     9091.0  ...
# ...               ...       ...      ...        ...  ...
# 68812             0.0       9.0      0.0     2684.0  ...
# 68813             0.0       8.0      0.0    13314.0  ...
# 68814             0.0       5.0      1.0     3715.0  ...
# 68815             1.0      21.0      0.0    59529.0  ...
# 68816             0.0      12.0      1.0    11882.0  ...
#
#        home_ownership_MORTGAGE  home_ownership_OWN  home_ownership_RENT  \
# 0                            0                   0                    1
# 1                            1                   0                    0
# 2                            1                   0                    0
# 3                            0                   0                    1
# 4                            1                   0                    0
# ...                        ...                 ...                  ...
# 68812                        0                   0                    1
# 68813                        0                   0                    1
# 68814                        1                   0                    0
# 68815                        1                   0                    0
# 68816                        1                   0                    0
#
#        verification_status_Source Verified  verification_status_Verified  \
# 0                                        1                             0
# 1                                        0                             1
# 2                                        0                             1
# 3                                        0                             1
# 4                                        0                             0
# ...                                    ...                           ...
# 68812                                    1                             0
# 68813                                    0                             0
# 68814                                    1                             0
# 68815                                    0                             1
# 68816                                    0                             1
#
#        issue_d_Jan-2019  issue_d_Mar-2019  initial_list_status_w  \
# 0                     0                 1                      1
# 1                     0                 1                      1
# 2                     0                 1                      1
# 3                     0                 1                      1
# 4                     0                 1                      1
# ...                 ...               ...                    ...
# 68812                 1                 0                      1
# 68813                 1                 0                      1
# 68814                 1                 0                      1
# 68815                 1                 0                      0
# 68816                 1                 0                      1
#
#        next_pymnt_d_May-2019  application_type_Joint App
# 0                          1                           0
# 1                          1                           0
# 2                          1                           0
# 3                          1                           0
# 4                          1                           0
# ...                      ...                         ...
# 68812                      1                           0
# 68813                      1                           0
# 68814                      1                           0
# 68815                      1                           0
# 68816                      1                           0
#
# [68817 rows x 86 columns]

# %%
# Create our target
y = df["loan_status"].to_frame()
y[:5] # showing first five to check
# Out:
#   loan_status
# 0    low_risk
# 1    low_risk
# 2    low_risk
# 3    low_risk
# 4    low_risk

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  home_ownership_MORTGAGE  home_ownership_OWN  \
# count   68817.000000  ...             68817.000000        68817.000000
# mean    17604.142828  ...                 0.526309            0.106747
# std     21835.880400  ...                 0.499311            0.308793
# min         0.000000  ...                 0.000000            0.000000
# 25%      6293.000000  ...                 0.000000            0.000000
# 50%     12068.000000  ...                 1.000000            0.000000
# 75%     21735.000000  ...                 1.000000            0.000000
# max    587191.000000  ...                 1.000000            1.000000
#
#        home_ownership_RENT  verification_status_Source Verified  \
# count         68817.000000                         68817.000000
# mean              0.357659                             0.373992
# std               0.479314                             0.483865
# min               0.000000                             0.000000
# 25%               0.000000                             0.000000
# 50%               0.000000                             0.000000
# 75%               1.000000                             1.000000
# max               1.000000                             1.000000
#
#        verification_status_Verified  issue_d_Jan-2019  issue_d_Mar-2019  \
# count                  68817.000000      68817.000000      68817.000000
# mean                       0.148001          0.451066          0.177238
# std                        0.355104          0.497603          0.381873
# min                        0.000000          0.000000          0.000000
# 25%                        0.000000          0.000000          0.000000
# 50%                        0.000000          0.000000          0.000000
# 75%                        0.000000          1.000000          0.000000
# max                        1.000000          1.000000          1.000000
#
#        initial_list_status_w  next_pymnt_d_May-2019  \
# count           68817.000000           68817.000000
# mean                0.876121               0.616839
# std                 0.329446               0.486161
# min                 0.000000               0.000000
# 25%                 1.000000               0.000000
# 50%                 1.000000               1.000000
# 75%                 1.000000               1.000000
# max                 1.000000               1.000000
#
#        application_type_Joint App
# count                68817.000000
# mean                     0.139660
# std                      0.346637
# min                      0.000000
# 25%                      0.000000
# 50%                      0.000000
# 75%                      0.000000
# max                      1.000000
#
# [8 rows x 86 columns]

# %%
# Check the balance of our target values
y["loan_status"].value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
# Split the X and y into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape
# Out:
# (51612, 86)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
X_scaler = scaler.fit(X_train)

# %%
# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
# Note: This took a very long time to run (kernel busy).  
rf_model = RandomForestClassifier(n_estimators=500, random_state=1)
rf_model = rf_model.fit(X_train_scaled, y_train)
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculated the balanced accuracy score
y_pred = rf_model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[    0,    87],
#        [    0, 17118]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.00      0.00      1.00      0.00      0.00      0.00        87
#    low_risk       0.99      1.00      0.00      1.00      0.00      0.00     17118
#
# avg / total       0.99      0.99      0.01      0.99      0.00      0.00     17205

# %%
# List the features sorted in descending order by feature importance
importances = rf_model.feature_importances_
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.08563541250598629, 'total_rec_prncp'),
#  (0.07192415076132597, 'total_rec_int'),
#  (0.06452707527870802, 'total_pymnt'),
#  (0.06271320500502256, 'total_pymnt_inv'),
#  (0.06165934923353948, 'last_pymnt_amnt'),
#  (0.021036288798939026, 'out_prncp_inv'),
#  (0.020447484378691448, 'installment'),
#  (0.019544383144227084, 'out_prncp'),
#  (0.01767816555893904, 'mo_sin_old_rev_tl_op'),
#  (0.01722267613000923, 'dti'),
#  (0.016424609819906105, 'mo_sin_old_il_acct'),
#  (0.014829992915577862, 'loan_amnt'),
#  (0.01440280783566716, 'max_bal_bc'),
#  (0.01439003432998312, 'revol_bal'),
#  (0.014252145991260982, 'bc_open_to_buy'),
#  (0.01420524443129963, 'total_rec_late_fee'),
#  (0.014192185508499716, 'total_bal_ex_mort'),
#  (0.014186977654122983, 'bc_util'),
#  (0.013461882668036971, 'annual_inc'),
#  (0.013423210391551914, 'tot_cur_bal'),
#  (0.013404660893440081, 'avg_cur_bal'),
#  (0.012890774354867195, 'tot_hi_cred_lim'),
#  (0.012665378707016992, 'total_bc_limit'),
#  (0.012601296515543344, 'total_bal_il'),
#  (0.012427099301425614, 'total_rev_hi_lim'),
#  (0.01221568845349096, 'total_il_high_credit_limit'),
#  (0.011840920990074638, 'int_rate'),
#  (0.011814777358416118, 'all_util'),
#  (0.011739543579389847, 'total_acc'),
#  (0.011616216875427106, 'mths_since_rcnt_il'),
#  (0.011535702962208133, 'il_util'),
#  (0.010711386431559913, 'mths_since_recent_bc'),
#  (0.010267634755727072, 'issue_d_Mar-2019'),
#  (0.010025317796104233, 'num_il_tl'),
#  (0.009990557655260067, 'mths_since_recent_inq'),
#  (0.009977955770222513, 'mo_sin_rcnt_rev_tl_op'),
#  (0.009970130949269173, 'num_rev_accts'),
#  (0.009705134672282152, 'num_actv_rev_tl'),
#  (0.009703837351756674, 'num_sats'),
#  (0.009207351397982778, 'num_rev_tl_bal_gt_0'),
#  (0.009035778036029455, 'open_acc'),
#  (0.008626544853976681, 'acc_open_past_24mths'),
#  (0.008598006718019437, 'mo_sin_rcnt_tl'),
#  (0.008315805907346378, 'num_actv_bc_tl'),
#  (0.00807541666366477, 'num_op_rev_tl'),
#  (0.007984275482953931, 'total_cu_tl'),
#  (0.007908490229570204, 'num_bc_tl'),
#  (0.007886461678227721, 'pct_tl_nvr_dlq'),
#  (0.007597209558451806, 'inq_last_12m'),
#  (0.007106233409198789, 'open_il_24m'),
#  (0.007079168113980951, 'open_rv_24m'),
#  (0.006363737372840123, 'inq_fi'),
#  (0.006345798663339154, 'percent_bc_gt_75'),
#  (0.006280275605298367, 'mort_acc'),
#  (0.00627316909078348, 'num_tl_op_past_12m'),
#  (0.006259129541193671, 'num_bc_sats'),
#  (0.00610333776723886, 'issue_d_Jan-2019'),
#  (0.006034821909063063, 'open_acc_6m'),
#  (0.005931873643581279, 'open_act_il'),
#  (0.005006778768401397, 'inq_last_6mths'),
#  (0.004914431283737336, 'next_pymnt_d_May-2019'),
#  (0.0049057181070582745, 'open_rv_12m'),
#  (0.004518125803965149, 'open_il_12m'),
#  (0.004041997717023496, 'delinq_2yrs'),
#  (0.0038443881820139137, 'tot_coll_amt'),
#  (0.0032671552248081624, 'num_accts_ever_120_pd'),
#  (0.002738229736211965, 'pub_rec_bankruptcies'),
#  (0.0023467045789397696, 'pub_rec'),
#  (0.002074526370178612, 'home_ownership_RENT'),
#  (0.001997255315414289, 'verification_status_Verified'),
#  (0.0019500478026487653, 'verification_status_Source Verified'),
#  (0.001944206733644039, 'home_ownership_OWN'),
#  (0.0019140911578241384, 'application_type_Joint App'),
#  (0.0017072541207150396, 'home_ownership_MORTGAGE'),
#  (0.0016525890346373807, 'num_tl_90g_dpd_24m'),
#  (0.0013500607763461453, 'initial_list_status_w'),
#  (0.001214483365149944, 'collections_12_mths_ex_med'),
#  (0.00033777256376494365, 'chargeoff_within_12_mths'),
#  (0.0, 'tax_liens'),
#  (0.0, 'recoveries'),
#  (0.0, 'policy_code'),
#  (0.0, 'num_tl_30dpd'),
#  (0.0, 'num_tl_120dpd_2m'),
#  (0.0, 'delinq_amnt'),
#  (0.0, 'collection_recovery_fee'),
#  (0.0, 'acc_now_delinq')]

# %%
# I also added this - Visualize the features by importance by selecting the top 10
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_[:10], X.columns[:10]), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(n_estimators=100, random_state=1)
eec.fit(X_train_scaled, y_train)
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = eec.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9263912558266958

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[   79,     8],
#        [  946, 16172]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.08      0.91      0.94      0.14      0.93      0.85        87
#    low_risk       1.00      0.94      0.91      0.97      0.93      0.86     17118
#
# avg / total       0.99      0.94      0.91      0.97      0.93      0.86     17205

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
#     Answer:  The Easy Ensemble had the best balanced accuracy score at 0.926.
#
# 2. Which model had the best recall score?
#
#     Answer:  The Balanced Random Forest had the best recall score at 0.99 vs Easy Ensemble at 0.94.
#
# 3. Which model had the best geometric mean score?
#
#     Answer:  The Easy Ensemble had the best geo score at 0.93.
#
# 4. What are the top three features?
#
#     Answer:  The top three features are installment, dti, and loan_amnt, as shown in the earlier visual.
